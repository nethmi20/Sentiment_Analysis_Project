# %%
import numpy as np

# %%
import json
with open('../artifacts/kaggle.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'username': 'nethmieranga', 'key': 'KGAT_24dd62e8dc1b4e043e70aeabe2f39084'}

# %%
# !pip install kaggle
# Out:
# Collecting kaggle
#   Downloading kaggle-1.8.3-py3-none-any.whl.metadata (16 kB)
# Collecting black>=24.10.0 (from kaggle)
#   Downloading black-25.12.0-cp314-cp314-win_amd64.whl.metadata (86 kB)
# Requirement already satisfied: bleach in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (6.3.0)
# Collecting kagglesdk<1.0,>=0.1.14 (from kaggle)
#   Downloading kagglesdk-0.1.14-py3-none-any.whl.metadata (13 kB)
# Collecting mypy>=1.15.0 (from kaggle)
#   Downloading mypy-1.19.1-cp314-cp314-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: packaging in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (25.0)
# Collecting protobuf (from kaggle)
#   Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: python-dateutil in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.9.0.post0)
# Collecting python-slugify (from kaggle)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: requests in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: six>=1.10 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (1.17.0)
# Collecting tqdm (from kaggle)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting types-requests (from kaggle)
#   Downloading types_requests-2.32.4.20260107-py3-none-any.whl.metadata (2.0 kB)
# Collecting types-tqdm (from kaggle)
#   Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from kaggle) (2.6.3)
# Collecting click>=8.0.0 (from black>=24.10.0->kaggle)
#   Using cached click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting mypy-extensions>=0.4.3 (from black>=24.10.0->kaggle)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black>=24.10.0->kaggle)
#   Downloading pathspec-1.0.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs>=2 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from black>=24.10.0->kaggle) (4.5.1)
# Collecting pytokens>=0.3.0 (from black>=24.10.0->kaggle)
#   Downloading pytokens-0.3.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: colorama in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from click>=8.0.0->black>=24.10.0->kaggle) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.6.0 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from mypy>=1.15.0->kaggle) (4.15.0)
# Collecting librt>=0.6.2 (from mypy>=1.15.0->kaggle)
#   Downloading librt-0.7.7-cp314-cp314-win_amd64.whl.metadata (1.4 kB)
# Requirement already satisfied: webencodings in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from bleach->kaggle) (0.5.1)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\desktop\sentiment_analysis_project\env\lib\site-packages (from requests->kaggle) (2026.1.4)
# Downloading kaggle-1.8.3-py3-none-any.whl (102 kB)
# Downloading kagglesdk-0.1.14-py3-none-any.whl (159 kB)
# Downloading black-25.12.0-cp314-cp314-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB ? eta -:--:--
#    --------------------- ------------------ 0.8/1.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.0/1.5 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.9 MB/s  0:00:00
# Using cached click-8.3.1-py3-none-any.whl (108 kB)
# Downloading mypy-1.19.1-cp314-cp314-win_amd64.whl (10.3 MB)
#    ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#    - -------------------------------------- 0.3/10.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/10.3 MB 2.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/10.3 MB 1.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/10.3 MB 1.7 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/10.3 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/10.3 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.6/10.3 MB 1.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 2.9/10.3 MB 1.8 MB/s eta 0:00:05
#    ------------ --------------------------- 3.1/10.3 MB 1.8 MB/s eta 0:00:05
#    -------------- ------------------------- 3.7/10.3 MB 1.8 MB/s eta 0:00:04
#    --------------- ------------------------ 3.9/10.3 MB 1.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 4.5/10.3 MB 1.8 MB/s eta 0:00:04
#    ------------------ --------------------- 4.7/10.3 MB 1.8 MB/s eta 0:00:04
#    ------------------- -------------------- 5.0/10.3 MB 1.7 MB/s eta 0:00:04
#    --------------------- ------------------ 5.5/10.3 MB 1.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 5.8/10.3 MB 1.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 6.0/10.3 MB 1.7 MB/s eta 0:00:03
#    ------------------------- -------------- 6.6/10.3 MB 1.7 MB/s eta 0:00:03
#    -------------------------- ------------- 6.8/10.3 MB 1.7 MB/s eta 0:00:03
#    --------------------------- ------------ 7.1/10.3 MB 1.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 7.3/10.3 MB 1.7 MB/s eta 0:00:02
#    ------------------------------ --------- 7.9/10.3 MB 1.7 MB/s eta 0:00:02
#    ------------------------------- -------- 8.1/10.3 MB 1.6 MB/s eta 0:00:02
#    -------------------------------- ------- 8.4/10.3 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 8.7/10.3 MB 1.6 MB/s eta 0:00:02
#    --------------------------------- ------ 8.7/10.3 MB 1.6 MB/s eta 0:00:02
#    ----------------------------------- ---- 9.2/10.3 MB 1.6 MB/s eta 0:00:01
#    ------------------------------------ --- 9.4/10.3 MB 1.6 MB/s eta 0:00:01
#    -------------------------------------- - 10.0/10.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  10.2/10.3 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 10.3/10.3 MB 1.6 MB/s  0:00:06
# Downloading librt-0.7.7-cp314-cp314-win_amd64.whl (45 kB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-1.0.2-py3-none-any.whl (54 kB)
# Downloading pytokens-0.3.0-py3-none-any.whl (12 kB)
# Downloading protobuf-6.33.2-cp310-abi3-win_amd64.whl (436 kB)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading types_requests-2.32.4.20260107-py3-none-any.whl (20 kB)
# Downloading types_tqdm-4.67.0.20250809-py3-none-any.whl (24 kB)
# Installing collected packages: text-unidecode, types-requests, tqdm, pytokens, python-slugify, protobuf, pathspec, mypy-extensions, librt, click, types-tqdm, mypy, kagglesdk, black, kaggle
#
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ----- ----------------------------------  2/15 [tqdm]
#    ---------- -----------------------------  4/15 [python-slugify]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ------------- --------------------------  5/15 [protobuf]
#    ---------------- -----------------------  6/15 [pathspec]
#    ---------------- -----------------------  6/15 [pathspec]
#    ------------------------ ---------------  9/15 [click]
#    ------------------------ ---------------  9/15 [click]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    ----------------------------- ---------- 11/15 [mypy]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    -------------------------------- ------- 12/15 [kagglesdk]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ---------------------------------- ----- 13/15 [black]
#    ------------------------------------- -- 14/15 [kaggle]
#    ------------------------------------- -- 14/15 [kaggle]
#    ---------------------------------------- 15/15 [kaggle]
#
# Successfully installed black-25.12.0 click-8.3.1 kaggle-1.8.3 kagglesdk-0.1.14 librt-0.7.7 mypy-1.19.1 mypy-extensions-1.1.0 pathspec-1.0.2 protobuf-6.33.2 python-slugify-8.0.4 pytokens-0.3.0 text-unidecode-1.3 tqdm-4.67.1 types-requests-2.32.4.20260107 types-tqdm-4.67.0.20250809

# %%
import os
os.environ['KAGGLE_USERNAME'] = data['username']
os.environ['KAGGLE_KEY'] = data['key']

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
api.dataset_download_files('dineshpiyasamara/sentiment-analysis-dataset', path ='../artifacts/')
# Out:
# Dataset URL: https://www.kaggle.com/datasets/dineshpiyasamara/sentiment-analysis-dataset

# %%
import zipfile
with zipfile.ZipFile('../artifacts/sentiment-analysis-dataset.zip', 'r') as zip_ref:
    zip_ref.extractall('../artifacts/')
